# %%
from datetime import date

from nwec.utility_reporting import scraper

# %%
cutoff_date = date(2025, 1, 1)

# %% [markdown]
# # Download quarterly reports from UTC docket

# %%
scraper.download_latest(submission_start_date=cutoff_date)
# Out:
# Downloaded avista_200281-AVA-Rpt-1-27-2025.xlsx for avista
# Downloaded cng_200281-CNGC-COVID-19-Term-Sheet-Data-01-31-25.xlsx for cng
# /home/peter/coding/nwec/nwec/utility_reporting/scraper.py:41: UserWarning: Skipping latest nwng report from 2024-12-20
#   warnings.warn(f"Skipping latest {utility_company.value} report from {submission_date}", stacklevel=1)
# Downloaded pac_200281-PAC-December-COVID-Rpt-1-30-25.xlsx for pac
# Downloaded pse_U-200281-PSE-Attach-A-December-2024-Data.xlsx for pse

# %% [markdown]
# # Move downloads to appropriate `raw` folder

# %%
scraper.rename_downloads(cutoff_date)
