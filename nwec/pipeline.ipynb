# %%
from datetime import date

from nwec.utility_reporting import scraper

# %%
cutoff_date = date(2025, 1, 1)

# %% [markdown]
# # Download quarterly reports from UTC docket

# %%
scraper.download_latest(submission_start_date=cutoff_date)
# Out:
# Downloaded avista_200281-AVA-Rpt-1-27-2025.xlsx for Avista Corporation (published on 2025-01-27)
# Downloaded cng_200281-CNGC-COVID-19-Term-Sheet-Data-01-31-25.xlsx for Cascade Natural Gas Corporation (published on 2025-01-31)
# /tmp/ipykernel_143054/2789417588.py:1: UserWarning: Skipping latest Northwest Natural Gas Company report that was published on 2024-12-20
#   scraper.download_latest(submission_start_date=cutoff_date)
# Downloaded pac_200281-PAC-December-COVID-Rpt-1-30-25.xlsx for PacifiCorp (published on 2025-01-30)
# Downloaded pse_U-200281-PSE-Attach-A-December-2024-Data.xlsx for Puget Sound Energy (published on 2025-01-03)

# %% [markdown]
# # Move downloads to appropriate `raw` folder

# %%
scraper.rename_downloads(cutoff_date)
