# %%
# %run ./avista.ipynb
# %run ./cng.ipynb
# %run ./nwng.ipynb
# %run ./pac.ipynb
# %run ./pse.ipynb
# Out:
# /home/peter/coding/nwec/nwec/utility_reporting/arrearages/arrearages.py:37: UserWarning: Multiple columns have at least 5 rows that match the ZIP code pattern; using the first.
#   nwec.utils.excel.infer_zip_column(arrearages)
# /home/peter/coding/nwec/nwec/utility_reporting/arrearages/arrearages.py:42: UserWarning: Multiple columns have at least 5 rows that match the customer class pattern; using the first.
#   infer_customer_class_column(arrearages)
# /home/peter/coding/nwec/nwec/utility_reporting/arrearages/arrearages.py:123: UserWarning: Multiple columns have at least 5 rows that match the ZIP code pattern; using the first.
#   zip_column = spreadsheet_df.select(pl.nth(nwec.utils.excel.infer_zip_column(spreadsheet_df)))
# /home/peter/coding/nwec/nwec/utility_reporting/arrearages/arrearages.py:127: UserWarning: Multiple columns have at least 5 rows that match the customer class pattern; using the first.
# ...
