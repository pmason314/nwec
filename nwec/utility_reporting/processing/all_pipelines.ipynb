# %%
from pathlib import Path

from nwec.utility_reporting.processing import assistance_pipeline, standard_pipeline

# %%
# %run arrearage_amounts.ipynb
# %run kli_arrearage_amounts.ipynb
# Out:
# Data validation passed with no errors.
# Data validation warnings:
#   - Arrearage_Amount: Found 12 negative values
# Data validation passed with no errors.

# %%
# Run assistance pipelines from assistance_pipelines.yaml
assistance_config_path = Path("assistance_pipelines.yaml")
assistance_pipelines = standard_pipeline.load_pipelines(assistance_config_path)
for pipeline in assistance_pipelines:
    assistance_pipeline.run_full_pipeline(pipeline)
# Out:
# Data validation passed with no errors for sheet '$ From COVID'.
# Saved '$ From COVID' to data/utility_reporting/processed/assistance_covid.arrow and data/utility_reporting/processed/assistance_covid.csv
# Data validation passed with no errors for sheet '$ From LIHEAP'.
# Saved '$ From LIHEAP' to data/utility_reporting/processed/assistance_liheap.arrow and data/utility_reporting/processed/assistance_liheap.csv
# Data validation passed with no errors for sheet '$ From Utility Assist.'.
# Saved '$ From Utility Assist.' to data/utility_reporting/processed/assistance_utility.arrow and data/utility_reporting/processed/assistance_utility.csv

# %%
# Run standard pipelines from pipelines.yaml
pipelines = standard_pipeline.load_pipelines()
for pipeline in pipelines:
    standard_pipeline.run_full_pipeline(pipeline)
# Out:
# Data validation passed with no errors for sheet 'Number of Disconnects'.
# Saved 'Number of Disconnects' to data/utility_reporting/processed/disconnections.arrow and data/utility_reporting/processed/disconnections.csv
# Data validation passed with no errors for sheet 'Number of Disconnect Notices'.
# Saved 'Number of Disconnect Notices' to data/utility_reporting/processed/disconnection_notices.arrow and data/utility_reporting/processed/disconnection_notices.csv
# Data validation passed with no errors for sheet 'No. of Customers w TPAs'.
# Saved 'No. of Customers w TPAs' to data/utility_reporting/processed/payment_agreements.arrow and data/utility_reporting/processed/payment_agreements.csv
# Data validation passed with no errors for sheet 'No. of Customers in Bill Assist'.
# Saved 'No. of Customers in Bill Assist' to data/utility_reporting/processed/bill_assist.arrow and data/utility_reporting/processed/bill_assist.csv
# Data validation passed with no errors for sheet 'No. Customers w Arrears'.
# Saved 'No. Customers w Arrears' to data/utility_reporting/processed/arrearage_counts.arrow and data/utility_reporting/processed/arrearage_counts.csv
# Data validation passed with no errors for sheet 'Total Uncollectible Arrears'.
# Saved 'Total Uncollectible Arrears' to data/utility_reporting/processed/uncollectible_arrears.arrow and data/utility_reporting/processed/uncollectible_arrears.csv
# Data validation passed with no errors for sheet 'No. Customers Refer to Agency'.
# Saved 'No. Customers Refer to Agency' to data/utility_reporting/processed/collection_agency_referrals.arrow and data/utility_reporting/processed/collection_agency_referrals.csv
# Data validation passed with no errors for sheet 'Total Amount of Bad Debt'.
# Saved 'Total Amount of Bad Debt' to data/utility_reporting/processed/bad_debt_amounts.arrow and data/utility_reporting/processed/bad_debt_amounts.csv
# Data validation warnings (Sheet: Revenue From Collection):
#   - Collections Revenue Amount: Found 514 negative values
# Data validation passed with no errors for sheet 'Revenue From Collection'.
# Saved 'Revenue From Collection' to data/utility_reporting/processed/collections_revenue.arrow and data/utility_reporting/processed/collections_revenue.csv
