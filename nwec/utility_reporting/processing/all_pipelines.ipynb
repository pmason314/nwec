# %%
from pathlib import Path

from nwec.utility_reporting.processing import assistance_pipeline, standard_pipeline

# %%
# %run arrearage_amounts.ipynb
# %run kli_arrearage_amounts.ipynb
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File /tmp/ipykernel_22508/2905342056.py:7
#       1 df = (
#       2     df.filter(pl.col("Customer Class").str.contains(r"(?i)res"))
#       3     .drop("Customer Class")
#       4     .rename({"value": core_value_column_name})
#       5 )
#       6 df = clean_utility_data(df, value_column_name=core_value_column_name)
# ----> 7 validate_data(df, value_column_name=core_value_column_name)
#
# File ~/coding/nwec/nwec/utils/cleaning.py:190, in validate_data(df, value_column_name, sheet_name)
#     188         for message in messages:
#     189             error_message += f"  - {field}: {message}\n"
# --> 190     raise ValueError(error_message)
#     192 sheet_info = f" for sheet '{sheet_name}'" if sheet_name else ""
#     193 print(f"Data validation passed with no errors{sheet_info}.")
#
# ValueError: Data validation failed:
#   - Duplicates: Found 904 duplicate key combinations. Sample duplicates: [{'Utility': 'Avista', 'Year': 2025, 'Month': 5, 'Zip Code': '99176', 'count': 4}, {'Utility': 'Avista', 'Year': 2025, 'Month': 9, 'Zip Code': '99020', 'count': 2}, {'Utility': 'Avista', 'Year': 2025, 'Month': 8, 'Zip Code': '99031', 'count': 4}, {'Utility': 'Avista', 'Year': 2025, 'Month': 7, 'Zip Code': '99018', 'count': 3}, {'Utility': 'Avista', 'Year': 2025, 'Month': 3, 'Zip Code': '99148', 'count': 4}]. This may indicate overlapping data from different reporting periods.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 get_ipython().run_line_magic('run', 'arrearage_amounts.ipynb')
#       2 get_ipython().run_line_magic('run', 'kli_arrearage_amounts.ipynb')
#
# File ~/coding/nwec/.venv/lib/python3.13/site-packages/IPython/core/interactiveshell.py:2511, in InteractiveShell.run_line_magic(self, magic_name, line, _stack_depth)
#    2509     kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2510 with self.builtin_trap:
# -> 2511     result = fn(*args, **kwargs)
#    2513 # The code below prevents the output from being displayed
#    2514 # when using magics with decorator @output_can_be_silenced
#    2515 # when the last Python token in the expression is a ';'.
#    2516 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# File ~/coding/nwec/.venv/lib/python3.13/site-packages/IPython/core/magics/execution.py:749, in ExecutionMagics.run(self, parameter_s, runner, file_finder)
#     747     with preserve_keys(self.shell.user_ns, '__file__'):
#     748         self.shell.user_ns['__file__'] = filename
# --> 749         self.shell.safe_execfile_ipy(filename, raise_exceptions=True)
#     750     return
#     752 # Control the response to exit() calls made by the script being run
#
# File ~/coding/nwec/.venv/lib/python3.13/site-packages/IPython/core/interactiveshell.py:3002, in InteractiveShell.safe_execfile_ipy(self, fname, shell_futures, raise_exceptions)
#    3000 result = self.run_cell(cell, silent=True, shell_futures=shell_futures)
#    3001 if raise_exceptions:
# -> 3002     result.raise_error()
#    3003 elif not result.success:
#    3004     break
#
# File ~/coding/nwec/.venv/lib/python3.13/site-packages/IPython/core/interactiveshell.py:327, in ExecutionResult.raise_error(self)
#     325     raise self.error_before_exec
#     326 if self.error_in_exec is not None:
# --> 327     raise self.error_in_exec
#
#     [... skipping hidden 1 frame]
#
# File /tmp/ipykernel_22508/2905342056.py:7
#       1 df = (
#       2     df.filter(pl.col("Customer Class").str.contains(r"(?i)res"))
#       3     .drop("Customer Class")
#       4     .rename({"value": core_value_column_name})
#       5 )
#       6 df = clean_utility_data(df, value_column_name=core_value_column_name)
# ----> 7 validate_data(df, value_column_name=core_value_column_name)
#
# File ~/coding/nwec/nwec/utils/cleaning.py:190, in validate_data(df, value_column_name, sheet_name)
#     188         for message in messages:
#     189             error_message += f"  - {field}: {message}\n"
# --> 190     raise ValueError(error_message)
#     192 sheet_info = f" for sheet '{sheet_name}'" if sheet_name else ""
#     193 print(f"Data validation passed with no errors{sheet_info}.")
#
# ValueError: Data validation failed:
#   - Duplicates: Found 904 duplicate key combinations. Sample duplicates: [{'Utility': 'Avista', 'Year': 2025, 'Month': 5, 'Zip Code': '99176', 'count': 4}, {'Utility': 'Avista', 'Year': 2025, 'Month': 9, 'Zip Code': '99020', 'count': 2}, {'Utility': 'Avista', 'Year': 2025, 'Month': 8, 'Zip Code': '99031', 'count': 4}, {'Utility': 'Avista', 'Year': 2025, 'Month': 7, 'Zip Code': '99018', 'count': 3}, {'Utility': 'Avista', 'Year': 2025, 'Month': 3, 'Zip Code': '99148', 'count': 4}]. This may indicate overlapping data from different reporting periods.

# %%
# Run assistance pipelines from assistance_pipelines.yaml
assistance_config_path = Path("assistance_pipelines.yaml")
assistance_pipelines = standard_pipeline.load_pipelines(assistance_config_path)
for pipeline in assistance_pipelines:
    assistance_pipeline.run_full_pipeline(pipeline)
# Out:
# Data validation passed with no errors for sheet '$ From COVID'.
# Saved '$ From COVID' to data/utility_reporting/processed/assistance_covid.arrow and data/utility_reporting/processed/assistance_covid.csv
# Data validation passed with no errors for sheet '$ From LIHEAP'.
# Saved '$ From LIHEAP' to data/utility_reporting/processed/assistance_liheap.arrow and data/utility_reporting/processed/assistance_liheap.csv
# Data validation passed with no errors for sheet '$ From Utility Assist.'.
# Saved '$ From Utility Assist.' to data/utility_reporting/processed/assistance_utility.arrow and data/utility_reporting/processed/assistance_utility.csv

# %%
# Run standard pipelines from pipelines.yaml
pipelines = standard_pipeline.load_pipelines()
for pipeline in pipelines:
    standard_pipeline.run_full_pipeline(pipeline)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 4
#       2 pipelines = standard_pipeline.load_pipelines()
#       3 for pipeline in pipelines:
# ----> 4     standard_pipeline.run_full_pipeline(pipeline)
#
# File ~/coding/nwec/nwec/utility_reporting/processing/standard_pipeline.py:72, in run_full_pipeline(pipeline)
#      70 df = df.filter(pl.col("Customer Class").str.contains(r"(?i)res")).drop("Customer Class")
#      71 df = clean_utility_data(df, value_column_name=pipeline.core_value_column_name)
# ---> 72 validate_data(df, value_column_name=pipeline.core_value_column_name, sheet_name=pipeline.sheet_name)
#      74 # Save the processed data
#      75 PROCESSED_UTILITY_DATA.mkdir(parents=True, exist_ok=True)
#
# File ~/coding/nwec/nwec/utils/cleaning.py:153, in validate_data(df, value_column_name, sheet_name)
#     151         for message in messages:
#     152             error_message += f"  - {field}: {message}\n"
# --> 153     raise ValueError(error_message)
#     155 sheet_info = f" for sheet '{sheet_name}'" if sheet_name else ""
#     156 print(f"Data validation passed with no errors{sheet_info}.")
#
# ValueError: Data validation failed (Sheet: Number of Disconnects):
#   - Zip Code: Found invalid zip codes: ['US/98087', 'US/98105', 'US/98108', 'US/98375', 'US/98257', 'US/98204', 'US/98406', 'US/98103', 'US/98409', 'US/98273']
