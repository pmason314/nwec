# %%
import itertools

from nwec.utility_reporting.arrearages.avista import avista_arrearages, avista_kli_arrearages

# %%
years = [2021, 2022, 2023, 2024]
quarters = [1, 2, 3, 4]
permutations = [(2020, 4), *list(itertools.product(years, quarters)), (2025, 1)]
avista_permutations = [(2020, 4), (2021, 4), (2022, 4), (2023, 4), (2024, 4)]

# %%
for year, quarter in avista_permutations:
    avista_arrearages(year, quarter)
    avista_kli_arrearages(year, quarter)
# Out:
# Processing Avista arrearages for 2020 Q4
# Processing Avista KLI arrearages for 2020 Q4
# Processing Avista arrearages for 2021 Q4
# Processing Avista KLI arrearages for 2021 Q4
# Processing Avista arrearages for 2022 Q4
# Processing Avista KLI arrearages for 2022 Q4
# Processing Avista arrearages for 2023 Q4
# Processing Avista KLI arrearages for 2023 Q4
# Processing Avista arrearages for 2024 Q4
# Processing Avista KLI arrearages for 2024 Q4
